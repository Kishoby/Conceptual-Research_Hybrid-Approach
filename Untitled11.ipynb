# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishoby/Conceptual-Research_Hybrid-Approach/blob/Data-Preprocessing/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install river --quiet

# %%
import pandas as pd
import numpy as np

from river import metrics, compose, preprocessing

# %%
multi_target_df = pd.read_csv("/content/drive/MyDrive/Research v2/Research 18.03.2026/Multi Target/cleaned_multi_target_dataset (1).csv")

print("Dataset shape:", multi_target_df.shape)
multi_target_df.head()
# Out:
# Dataset shape: (130003, 18)
#    visibility_km  last_updated_epoch  air_quality_Ozone  latitude  \
# 0           16.0          1715849100               62.2     46.60
# 1           10.0          1715849100               23.3     14.10
# 2           10.0          1715849100                5.9     13.71
# 3            5.0          1715849100                0.4     14.62
# 4           10.0          1715849100               34.0     17.25
#
#    air_quality_PM10  condition_text  air_quality_Sulphur_dioxide  uv_index  \
# 0               7.1               2                          0.2       1.0
# 1              25.3              32                          1.4       1.0
# 2              28.1              23                          7.5       1.0
# 3             178.1              19                         19.3       1.0
# 4              32.1              30                          0.2       1.0
#
#    air_quality_Nitrogen_dioxide  feels_like_celsius  precip_mm  cloud  \
# 0                           2.5                16.1       0.00      0
# 1                           3.7                25.3       0.28     37
# 2                           7.7                30.2       0.30     50
# 3                          35.0                20.0       0.09    100
# 4                           0.3                29.6       0.00     94
#
#    pressure_mb  longitude  air_quality_Carbon_Monoxide  air_quality_PM2.5  \
# 0       1012.0    -120.49                        198.6                6.3
# 1       1017.0     -87.22                        377.2               19.0
# 2       1010.0     -89.20                        460.6               20.4
# 3       1019.0     -90.53                       2243.0              132.0
# 4       1007.0     -88.77                        307.1                7.7
#
#    temperature_celsius  humidity
# 0                 16.1        58
# 1                 23.0        78
# 2                 26.0        94
# 3                 20.0        88
# 4                 26.0        89

# %%
targets = [
    "air_quality_PM2.5",
    "temperature_celsius",
    "humidity"
]

features = [col for col in multi_target_df.columns if col not in targets]

print("Targets:", targets)
print("Number of features:", len(features))
print(features)
# Out:
# Targets: ['air_quality_PM2.5', 'temperature_celsius', 'humidity']
# Number of features: 15
# ['visibility_km', 'last_updated_epoch', 'air_quality_Ozone', 'latitude', 'air_quality_PM10', 'condition_text', 'air_quality_Sulphur_dioxide', 'uv_index', 'air_quality_Nitrogen_dioxide', 'feels_like_celsius', 'precip_mm', 'cloud', 'pressure_mb', 'longitude', 'air_quality_Carbon_Monoxide']

# %%
for col in targets:
    multi_target_df[f"{col}_lag1"] = multi_target_df[col].shift(1)
    multi_target_df[f"{col}_lag2"] = multi_target_df[col].shift(2)

multi_target_df = multi_target_df.dropna().reset_index(drop=True)

print("Shape after adding target lags:", multi_target_df.shape)
multi_target_df.head()
# Out:
# Shape after adding target lags: (130001, 24)
#    visibility_km  last_updated_epoch  air_quality_Ozone  latitude  \
# 0           10.0          1715849100                5.9     13.71
# 1            5.0          1715849100                0.4     14.62
# 2           10.0          1715849100               34.0     17.25
# 3           10.0          1715849100               14.3     12.15
# 4            7.0          1715849100                0.0      9.97
#
#    air_quality_PM10  condition_text  air_quality_Sulphur_dioxide  uv_index  \
# 0              28.1              23                          7.5       1.0
# 1             178.1              19                         19.3       1.0
# 2              32.1              30                          0.2       1.0
# 3              14.7              41                         11.4       1.0
# 4              23.3               4                          6.6       1.0
#
#    air_quality_Nitrogen_dioxide  feels_like_celsius  ...  \
# 0                           7.7                30.2  ...
# 1                          35.0                20.0  ...
# 2                           0.3                29.6  ...
# 3                           6.5                30.6  ...
# 4                          10.9                21.0  ...
#
#    air_quality_Carbon_Monoxide  air_quality_PM2.5  temperature_celsius  \
# 0                        460.6               20.4                 26.0
# 1                       2243.0              132.0                 20.0
# 2                        307.1                7.7                 26.0
# 3                        500.7               11.7                 27.2
# 4                       1161.6               21.7                 21.0
#
#    humidity  air_quality_PM2.5_lag1  air_quality_PM2.5_lag2  \
# 0        94                    19.0                     6.3
# 1        88                    20.4                    19.0
# 2        89                   132.0                    20.4
# 3        80                     7.7                   132.0
# 4       100                    11.7                     7.7
#
#    temperature_celsius_lag1  temperature_celsius_lag2  humidity_lag1  \
# 0                      23.0                      16.1           78.0
# 1                      26.0                      23.0           94.0
# 2                      20.0                      26.0           88.0
# 3                      26.0                      20.0           89.0
# 4                      27.2                      26.0           80.0
#
#    humidity_lag2
# 0           58.0
# 1           78.0
# 2           94.0
# 3           88.0
# 4           89.0
#
# [5 rows x 24 columns]

# %%
features = [col for col in multi_target_df.columns if col not in targets]

print("Updated feature count:", len(features))
print(features)
# Out:
# Updated feature count: 21
# ['visibility_km', 'last_updated_epoch', 'air_quality_Ozone', 'latitude', 'air_quality_PM10', 'condition_text', 'air_quality_Sulphur_dioxide', 'uv_index', 'air_quality_Nitrogen_dioxide', 'feels_like_celsius', 'precip_mm', 'cloud', 'pressure_mb', 'longitude', 'air_quality_Carbon_Monoxide', 'air_quality_PM2.5_lag1', 'air_quality_PM2.5_lag2', 'temperature_celsius_lag1', 'temperature_celsius_lag2', 'humidity_lag1', 'humidity_lag2']

# %%
split_index = int(0.8 * len(multi_target_df))

train_df = multi_target_df.iloc[:split_index].copy()
test_df = multi_target_df.iloc[split_index:].copy()

print("Train shape:", train_df.shape)
print("Test shape :", test_df.shape)
# Out:
# Train shape: (104000, 24)
# Test shape : (26001, 24)

# %%
n_train = len(train_df)

iter1 = train_df.iloc[:int(0.33 * n_train)].copy()
iter2 = train_df.iloc[int(0.33 * n_train):int(0.66 * n_train)].copy()
iter3 = train_df.iloc[int(0.66 * n_train):].copy()

print("Iteration 1 shape:", iter1.shape)
print("Iteration 2 shape:", iter2.shape)
print("Iteration 3 shape:", iter3.shape)
# Out:
# Iteration 1 shape: (34320, 24)
# Iteration 2 shape: (34320, 24)
# Iteration 3 shape: (35360, 24)

# %%
def build_hybrid_model():
    try:
        from river import forest
        model = forest.ARFRegressor(
            n_models=20,
            max_features="sqrt",
            lambda_value=6,
            seed=42
        )
        model_name = "River ARF Hybrid"
    except Exception:
        from river import tree
        model = compose.Pipeline(
            preprocessing.StandardScaler(),
            tree.HoeffdingAdaptiveTreeRegressor(
                grace_period=50,
                delta=1e-5,
                leaf_prediction="adaptive"
            )
        )
        model_name = "River HAT Hybrid"

    return model, model_name

# %%
target_models = {}
model_name = None

for target in targets:
    model, model_name = build_hybrid_model()
    target_models[target] = model

print("Using hybrid model:", model_name)
print("Models created for targets:", list(target_models.keys()))
# Out:
# Using hybrid model: River ARF Hybrid
# Models created for targets: ['air_quality_PM2.5', 'temperature_celsius', 'humidity']

# %%
def run_multi_target_hybrid_iteration(data, target_models, iteration_name, features, targets, warmup=False):
    metric_store = {
        target: {
            "mse": metrics.MSE(),
            "rmse": metrics.RMSE(),
            "mae": metrics.MAE(),
            "r2": metrics.R2()
        }
        for target in targets
    }

    first_part = int(0.1 * len(data)) if warmup else 0

    for i, (_, row) in enumerate(data.iterrows()):
        x = row[features].to_dict()

        for target in targets:
            y = row[target]

            # warmup for first part of iteration 1
            if i < first_part:
                target_models[target].learn_one(x, y)
                continue

            y_pred = target_models[target].predict_one(x)
            if y_pred is None:
                y_pred = 0.0

            metric_store[target]["mse"].update(y, y_pred)
            metric_store[target]["rmse"].update(y, y_pred)
            metric_store[target]["mae"].update(y, y_pred)
            metric_store[target]["r2"].update(y, y_pred)

            target_models[target].learn_one(x, y)

    rows = []
    for target in targets:
        mse = metric_store[target]["mse"].get()
        rmse = metric_store[target]["rmse"].get()
        mae = metric_store[target]["mae"].get()
        r2 = metric_store[target]["r2"].get()
        acc = r2 * 100

        rows.append([
            iteration_name,
            model_name,
            target,
            mse,
            rmse,
            mae,
            r2,
            acc
        ])

    results_df = pd.DataFrame(
        rows,
        columns=["Iteration", "Model", "Target", "MSE", "RMSE", "MAE", "R2", "Accuracy (%)"]
    ).round(3)

    print(f"\n{iteration_name} Results")
    display(results_df)

    return target_models, results_df

# %%
target_models, hybrid_iter1_df = run_multi_target_hybrid_iteration(
    iter1,
    target_models,
    "Iteration 1",
    features,
    targets,
    warmup=True
)
# Out:
# Iteration 1 Results
#      Iteration             Model               Target      MSE    RMSE    MAE  \
# 0  Iteration 1  River ARF Hybrid    air_quality_PM2.5  462.570  21.507  5.035
# 1  Iteration 1  River ARF Hybrid  temperature_celsius    2.508   1.584  1.084
# 2  Iteration 1  River ARF Hybrid             humidity  155.232  12.459  9.818
#
#       R2  Accuracy (%)
# 0  0.771        77.117
# 1  0.955        95.489
# 2  0.752        75.246

# %%
target_models, hybrid_iter2_df = run_multi_target_hybrid_iteration(
    iter2,
    target_models,
    "Iteration 2",
    features,
    targets,
    warmup=False
)
# Out:
# Iteration 2 Results
#      Iteration             Model               Target      MSE    RMSE  \
# 0  Iteration 2  River ARF Hybrid    air_quality_PM2.5  432.338  20.793
# 1  Iteration 2  River ARF Hybrid  temperature_celsius    3.331   1.825
# 2  Iteration 2  River ARF Hybrid             humidity  170.010  13.039
#
#       MAE     R2  Accuracy (%)
# 0   7.689  0.712        71.192
# 1   1.072  0.968        96.841
# 2  10.102  0.695        69.452

# %%
target_models, hybrid_iter3_df = run_multi_target_hybrid_iteration(
    iter3,
    target_models,
    "Iteration 3",
    features,
    targets,
    warmup=False
)
# Out:
# Iteration 3 Results
#      Iteration             Model               Target      MSE    RMSE    MAE  \
# 0  Iteration 3  River ARF Hybrid    air_quality_PM2.5  150.964  12.287  4.592
# 1  Iteration 3  River ARF Hybrid  temperature_celsius    1.296   1.139  0.736
# 2  Iteration 3  River ARF Hybrid             humidity  123.059  11.093  8.506
#
#       R2  Accuracy (%)
# 0  0.853        85.316
# 1  0.976        97.616
# 2  0.781        78.057
